# %% [markdown]
# <h2>Graph Neural Networks From Scratch</h2><br>
#
# A gentle introduction to Graph Neural Networks(GNNs). We will use an interaction network (a kind of GNN) for the task of predicting the trajectory of planets in a solar system.
#
#
# Attributions:<br>
# Physics Engine: https://github.com/jaesik817/Interaction-networks_tensorflow/blob/master/physics_engine.py<br>
# Original Paper: https://arxiv.org/pdf/1612.00222v1.pdf<br>
# On Graph Neural Networks: https://arxiv.org/abs/1806.01261 (How this architecture can be extended for link prediction, graph and subgraph prediction tasks)<br>

# %%
import os
import random
import time

import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader

from Physics_Engine import gen

from IPython.display import clear_output
from tqdm import tqdm
import matplotlib.pyplot as plt
import pygame
import sys

# %% [markdown]
# <h2>Generating a dataset </h2>
#
# The gen function generates a solar system:<br>
#
# gen(num_planets, orbit, num_points)<br>
# num_planets: Number of planets in the solar system<br>
# orbit: If set to true, has one planet with a lot of mass that acts like a sun<br>
# num_points: Amount of data points/length of the trajectory <br>

# %%
num_planets  = 3 
num_node_features = 5 

num_edges  = num_planets * (num_planets - 1) 
num_edge_features = 1


data = gen(num_planets, True, 1000)


class planet:
    def __init__(self, name, mass, pos_x, pos_y):
        # assertions about horizon of experiment
        self.name = name
        self.radius = max(10, int(mass/2.5))
        self.mass = mass
        self.pos_x = pos_x
        self.pos_y = pos_y
        self.color = (random.randrange(0,255), random.randrange(0,255), random.randrange(0,255))
    def get_pos(self, timestamp):
        return (int(self.pos_x[timestamp]), int(self.pos_y[timestamp]))
    
planets = []

for p in range(data.shape[1]):
    mass = data[0][p][0]
    pos_x = data[:,p,1]
    pos_y = data[:,p,2]
    planets.append(planet(chr(ord('a')+p), mass, pos_x, pos_y))

# %% [markdown]
# <h2>Basic Statistics</h2>
#
# Each Planet is described by 5 features: [Mass, Pos_X, Pos_Y, Speed_X, Speed_Y]<br>
# The task is to predict the next [Pos_X, Pos_Y]<br>
# Imagine you can run this simulator unlimited times to generate unlimited training data

# %%
print('Number of Planets:', num_planets)
print('Number of Features:', num_node_features)
print('Dataset shape:', data.shape)

print()
print('Planet weights:', data[0,:,0])

print()
print('Features: [Mass, Pos_X, Pos_Y, Speed_X, Speed_Y]')
print('Features example:',data[10,1,:])

avg_dist = np.mean(np.abs(data[1:999,2,1] - data[0:998,2,1])) + np.mean(np.abs(data[1:999,2,2] - data[0:998,2,2]))
# Out:
# Number of Planets: 3
# Number of Features: 5
# Dataset shape: (1000, 3, 5)
#
# Planet weights: [100.           5.81178715   1.32853627]
#
# Features: [Mass, Pos_X, Pos_Y, Speed_X, Speed_Y]
# Features example: [   5.81178715  -37.48360254   33.78708085 -108.87959659 -168.42588237]

# %% [markdown]
# <h2>Visualization</h2>

# %%
pygame.init()

screen = pygame.display.set_mode((800,800))

pygame.display.set_caption('Mock Solar System')

fps = pygame.time.Clock()

paused = False


def render(timestep):

    screen.fill((0,0,0))
    
    for planet in planets:
        pos = planet.get_pos(timestep)
        pygame.draw.circle(screen, planet.color, (pos[0]+250, pos[1]+250), planet.radius, 0)

    pygame.display.update()

    fps.tick(60)


timestep = 0


while True:

    pygame.event.get()
        
    if timestep > 500:
        pygame.quit()
        sys.exit
        break


    render(timestep)
    timestep+=1

# %% [markdown]
# <h2> A simple NN architecture</h2>

# %%
# Define network dimensions
n_input_dim = data.shape[1] * data.shape[2]
# Layer size
n_hidden = 32 
n_output = 6 
learning_rate = 0.005

# Network
net = nn.Sequential(
    nn.Linear(n_input_dim, n_hidden),
    nn.ReLU(),
    nn.Linear(n_hidden, n_output))

loss_func = nn.MSELoss()

optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)
    
print(net)
# Out:
# Sequential(
#   (0): Linear(in_features=15, out_features=32, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=32, out_features=6, bias=True)
# )

# %% [markdown]
# <h2> Train a simple NN model</h2>
#
# The caveat being that the train and test solar systems are different

# %%
train_losses = []
test_losses = []
train_accuracy = []
epochs = 1000
for i in range(epochs):
    # Every epoch, a 3-planet solar system is generated
    
    data = gen(num_planets, True, 100)

    train_X = torch.FloatTensor(data[0:80].reshape(80,-1))
    test_X = torch.FloatTensor(data[80:-1].reshape(19,-1))

    train_y = torch.FloatTensor(data[1:81,:,:2].reshape(80,-1))
    test_y = torch.FloatTensor(data[81:,:,:2].reshape(19,-1))
    
    # Train

    y_hat = net(train_X)
    loss = loss_func(y_hat, train_y)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    # Test
    
    y_hat = net(test_X)
    test_loss = loss_func(y_hat, test_y)
    optimizer.zero_grad()
    
    train_losses.append(loss.item())
    test_losses.append(test_loss.item())
    
    
    
    print('Epoch:', i, 'Train RMSE:', round(np.sqrt(loss.item()),3), 'Test RMSE', round(np.sqrt(test_loss.item()), 3))
# Out:
# Epoch: 0 Train RMSE: 38.607 Test RMSE 33.882
# Epoch: 1 Train RMSE: 56.189 Test RMSE 46.244
# Epoch: 2 Train RMSE: 41.685 Test RMSE 42.315
# Epoch: 3 Train RMSE: 40.179 Test RMSE 72.271
# Epoch: 4 Train RMSE: 41.91 Test RMSE 42.039
# Epoch: 5 Train RMSE: 30.916 Test RMSE 22.739
# Epoch: 6 Train RMSE: 41.596 Test RMSE 34.508
# Epoch: 7 Train RMSE: 40.192 Test RMSE 30.579
# Epoch: 8 Train RMSE: 36.37 Test RMSE 28.739
# Epoch: 9 Train RMSE: 26.861 Test RMSE 20.272
# Epoch: 10 Train RMSE: 36.005 Test RMSE 30.579
# Epoch: 11 Train RMSE: 43.622 Test RMSE 37.111
# Epoch: 12 Train RMSE: 37.606 Test RMSE 33.686
# Epoch: 13 Train RMSE: 40.686 Test RMSE 33.131
# Epoch: 14 Train RMSE: 59.869 Test RMSE 23.153
# Epoch: 15 Train RMSE: 17.417 Test RMSE 68.534
# Epoch: 16 Train RMSE: 43.515 Test RMSE 48.62
# Epoch: 17 Train RMSE: 36.913 Test RMSE 72.805
# Epoch: 18 Train RMSE: 37.727 Test RMSE 65.11
# Epoch: 19 Train RMSE: 41.021 Test RMSE 43.483
# Epoch: 20 Train RMSE: 34.724 Test RMSE 33.941
# Epoch: 21 Train RMSE: 33.435 Test RMSE 22.99
# Epoch: 22 Train RMSE: 11.788 Test RMSE 30.307
# Epoch: 23 Train RMSE: 41.452 Test RMSE 32.04
# Epoch: 24 Train RMSE: 44.055 Test RMSE 31.703
# Epoch: 25 Train RMSE: 31.252 Test RMSE 14.651
# Epoch: 26 Train RMSE: 23.247 Test RMSE 26.234
# Epoch: 27 Train RMSE: 17.816 Test RMSE 11.05
# Epoch: 28 Train RMSE: 35.27 Test RMSE 20.344
# Epoch: 29 Train RMSE: 17.331 Test RMSE 34.651
# Epoch: 30 Train RMSE: 48.805 Test RMSE 39.479
# Epoch: 31 Train RMSE: 15.218 Test RMSE 9.067
# Epoch: 32 Train RMSE: 55.056 Test RMSE 31.41
# Epoch: 33 Train RMSE: 33.768 Test RMSE 33.787
# Epoch: 34 Train RMSE: 37.134 Test RMSE 36.196
# Epoch: 35 Train RMSE: 41.587 Test RMSE 47.679
# Epoch: 36 Train RMSE: 45.749 Test RMSE 79.53
# Epoch: 37 Train RMSE: 45.147 Test RMSE 43.788
# Epoch: 38 Train RMSE: 39.727 Test RMSE 16.473
# Epoch: 39 Train RMSE: 31.947 Test RMSE 21.063
# Epoch: 40 Train RMSE: 13.54 Test RMSE 19.163
# Epoch: 41 Train RMSE: 23.083 Test RMSE 28.003
# Epoch: 42 Train RMSE: 23.541 Test RMSE 17.201
# Epoch: 43 Train RMSE: 27.873 Test RMSE 27.692
# Epoch: 44 Train RMSE: 39.057 Test RMSE 33.868
# Epoch: 45 Train RMSE: 18.25 Test RMSE 26.032
# Epoch: 46 Train RMSE: 26.199 Test RMSE 29.125
# Epoch: 47 Train RMSE: 27.696 Test RMSE 29.225
# Epoch: 48 Train RMSE: 28.278 Test RMSE 24.482
# Epoch: 49 Train RMSE: 29.532 Test RMSE 26.398
# Epoch: 50 Train RMSE: 44.817 Test RMSE 41.674
# Epoch: 51 Train RMSE: 23.89 Test RMSE 20.414
# Epoch: 52 Train RMSE: 31.323 Test RMSE 29.278
# Epoch: 53 Train RMSE: 24.324 Test RMSE 20.752
# Epoch: 54 Train RMSE: 32.567 Test RMSE 30.655
# Epoch: 55 Train RMSE: 33.935 Test RMSE 26.721
# Epoch: 56 Train RMSE: 24.893 Test RMSE 16.605
# Epoch: 57 Train RMSE: 21.289 Test RMSE 11.751
# Epoch: 58 Train RMSE: 29.735 Test RMSE 24.747
# Epoch: 59 Train RMSE: 32.025 Test RMSE 32.763
# Epoch: 60 Train RMSE: 23.262 Test RMSE 45.673
# Epoch: 61 Train RMSE: 30.227 Test RMSE 24.394
# Epoch: 62 Train RMSE: 26.404 Test RMSE 15.001
# Epoch: 63 Train RMSE: 26.247 Test RMSE 17.113
# Epoch: 64 Train RMSE: 37.04 Test RMSE 13.197
# Epoch: 65 Train RMSE: 19.554 Test RMSE 17.555
# Epoch: 66 Train RMSE: 25.927 Test RMSE 20.193
# Epoch: 67 Train RMSE: 35.494 Test RMSE 29.354
# Epoch: 68 Train RMSE: 24.043 Test RMSE 20.835
# Epoch: 69 Train RMSE: 19.384 Test RMSE 11.839
# Epoch: 70 Train RMSE: 30.474 Test RMSE 26.917
# Epoch: 71 Train RMSE: 29.846 Test RMSE 33.492
# Epoch: 72 Train RMSE: 23.129 Test RMSE 19.689
# Epoch: 73 Train RMSE: 27.871 Test RMSE 22.018
# Epoch: 74 Train RMSE: 30.177 Test RMSE 31.336
# Epoch: 75 Train RMSE: 19.716 Test RMSE 7.634
# Epoch: 76 Train RMSE: 29.017 Test RMSE 26.684
# Epoch: 77 Train RMSE: 19.4 Test RMSE 24.144
# Epoch: 78 Train RMSE: 24.464 Test RMSE 19.328
# Epoch: 79 Train RMSE: 24.554 Test RMSE 27.626
# Epoch: 80 Train RMSE: 35.226 Test RMSE 32.06
# Epoch: 81 Train RMSE: 26.031 Test RMSE 25.939
# Epoch: 82 Train RMSE: 38.343 Test RMSE 31.878
# Epoch: 83 Train RMSE: 21.525 Test RMSE 21.942
# Epoch: 84 Train RMSE: 20.592 Test RMSE 16.431
# Epoch: 85 Train RMSE: 15.572 Test RMSE 15.609
# Epoch: 86 Train RMSE: 30.21 Test RMSE 34.15
# Epoch: 87 Train RMSE: 25.361 Test RMSE 23.236
# Epoch: 88 Train RMSE: 14.772 Test RMSE 17.385
# Epoch: 89 Train RMSE: 14.124 Test RMSE 11.194
# Epoch: 90 Train RMSE: 41.287 Test RMSE 23.991
# Epoch: 91 Train RMSE: 21.747 Test RMSE 62.49
# Epoch: 92 Train RMSE: 27.758 Test RMSE 34.541
# Epoch: 93 Train RMSE: 17.732 Test RMSE 21.7
# Epoch: 94 Train RMSE: 27.946 Test RMSE 20.722
# Epoch: 95 Train RMSE: 12.292 Test RMSE 13.047
# Epoch: 96 Train RMSE: 24.052 Test RMSE 19.602
# Epoch: 97 Train RMSE: 22.337 Test RMSE 11.016
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7f77db703891> in <module>()
#      18     y_hat = net(train_X)
#      19     loss = loss_func(y_hat, train_y)
# ---> 20     loss.backward()
#      21     optimizer.step()
#      22     optimizer.zero_grad()
#
# c:\users\sroy3\appdata\local\programs\python\python35\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# c:\users\sroy3\appdata\local\programs\python\python35\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
# %matplotlib inline

# Plotting the loss

t = range(0,len(train_losses))[100:]
a = train_losses[100:]
b = test_losses[100:]


plt.plot(t, a, 'r') # plotting t, a separately 
plt.plot(t, b, 'b') # plotting t, b separately 
plt.show()

# %%
# Helper function to get a batch of data for the next part


def get_batch(train = True):
    
    batch_size = 99
    
    num_planets  = random.randrange(1,6)
    
    if train:
        num_planets = 3
    
    num_node_features = 5 
    num_edges  = num_planets * (num_planets - 1) 
    num_edge_features = 1


    data = gen(num_planets, True, 100)
    
    X = data[0:99]
    y = data[1:100,:,:2]

    edge_list = []

    for i in range(num_planets):
        for j in range(num_planets):
            if i!=j:
                edge_list.append((i,j))
                


    edge_out = np.zeros((batch_size, num_edges, num_planets), dtype=float);
    edge_in = np.zeros((batch_size, num_edges, num_planets), dtype=float);
    edge_features = Variable(torch.FloatTensor(np.zeros((batch_size, num_edges, num_edge_features))))


    row = 0
    for edge in edge_list:
        edge_out[0,row,edge[0]] = 1
        edge_in[0,row,edge[1]] = 1

        row+=1


    edge_out = Variable(torch.FloatTensor(edge_out))
    edge_in = Variable(torch.FloatTensor(edge_in))
         

    data = Variable(torch.FloatTensor(X))
    labels = Variable(torch.FloatTensor(y.reshape(-1,2)))
    
    return data, edge_out, edge_in, edge_features, labels

# %% [markdown]
# <h2>Graph Neural Network</h2>
#
# Motivation behind a graph neural network:<br>
#
# 1) The solution should explicitly learn interactions between objects <br>
# 2) The solution should treat individual nodes and edges as a separate unit (Instead of concatenating all the features in our vanilla NN implementation. <br>
# 3) The solution should generalize beyond different systems and different number of planets.<br>
# 4) The solution should be invariant to permutation (No fixed ordering of planets like the vanilla NN).

# %%
class graph_NN(nn.Module):
    def __init__(self, num_node_features, num_edge_features, hidden_dim, embedding_dim, output_dim):
        super(graph_NN, self).__init__()
        
        self.edge_NN = nn.Sequential(nn.Linear(2 * num_node_features + num_edge_features, hidden_dim), 
                                     nn.ReLU(), 
                                     nn.Linear(hidden_dim, embedding_dim))
        
        self.node_NN = nn.Sequential(nn.Linear(num_node_features + embedding_dim, hidden_dim),
                                     nn.ReLU(),
                                     nn.Linear(hidden_dim, output_dim),
                                    )
        print('edge_NN:', self.edge_NN)
        print('node_NN:', self.node_NN)
    
    def forward(self, data, edge_out, edge_in, edge_features):
        
        first_vertex_data   = edge_out.bmm(data)
        second_vertex_data = edge_in.bmm(data)
        
        edge_embeddings = self.edge_NN(torch.cat([first_vertex_data, second_vertex_data, edge_features], 2))
        
        aggregated_edge_embeddings = edge_in.permute(0,2,1).bmm(edge_embeddings)
        
        predicted = self.node_NN(torch.cat([data,aggregated_edge_embeddings], 2).view(-1, num_node_features + embedding_dim))
        
        return predicted

# %%
n_epoch = 1000
lr = 0.005
hidden_dim = 16
embedding_dim = 8
output_dim = 2
num_node_features = 5
num_edge_features = 1

graph_NN_instance = graph_NN(num_node_features, num_edge_features,  hidden_dim, embedding_dim, output_dim)
optimizer = optim.Adam(graph_NN_instance.parameters(),  lr=lr)
criterion = nn.MSELoss()
# Out:
# edge_NN: Sequential(
#   (0): Linear(in_features=11, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=16, out_features=8, bias=True)
# )
# node_NN: Sequential(
#   (0): Linear(in_features=13, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=16, out_features=2, bias=True)
# )

# %% [markdown]
# <h2>Train the Graph Neural Network!</h2>
#
# At training time, we use a 3 planet solar system. At test time, the solar system is randomly generated to have 1 to 6 planets!

# %%
losses = []

for epoch in range(1000):
    data, edge_out, edge_in, edge_features, labels = get_batch()
    
    predicted = graph_NN_instance(data, edge_out, edge_in, edge_features)
    
    loss = criterion(predicted, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    losses.append(np.sqrt(loss.data))
    
    data_test, edge_out, edge_in, edge_features, labels = get_batch(False)    
    predicted = graph_NN_instance(data_test, edge_out, edge_in, edge_features)
    test_loss = criterion(predicted, labels)

    print('Epoch:', epoch, 'Test RMSE:', np.sqrt(test_loss.data),'Test Planets:', data_test.shape[1])
# Out:
# Epoch: 0 Test RMSE: tensor(62.5799) Test Planets: 1
# Epoch: 1 Test RMSE: tensor(62.0537) Test Planets: 1
# Epoch: 2 Test RMSE: tensor(43.1503) Test Planets: 5
# Epoch: 3 Test RMSE: tensor(45.4547) Test Planets: 2
# Epoch: 4 Test RMSE: tensor(41.8911) Test Planets: 5
# Epoch: 5 Test RMSE: tensor(42.8199) Test Planets: 4
# Epoch: 6 Test RMSE: tensor(44.6206) Test Planets: 2
# Epoch: 7 Test RMSE: tensor(41.0803) Test Planets: 5
# Epoch: 8 Test RMSE: tensor(35.4738) Test Planets: 5
# Epoch: 9 Test RMSE: tensor(40.8927) Test Planets: 2
# Epoch: 10 Test RMSE: tensor(43.4359) Test Planets: 2
# Epoch: 11 Test RMSE: tensor(38.5295) Test Planets: 4
# Epoch: 12 Test RMSE: tensor(38.7150) Test Planets: 3
# Epoch: 13 Test RMSE: tensor(37.5524) Test Planets: 3
# Epoch: 14 Test RMSE: tensor(32.8031) Test Planets: 4
# Epoch: 15 Test RMSE: tensor(33.1974) Test Planets: 4
# Epoch: 16 Test RMSE: tensor(41.9383) Test Planets: 3
# Epoch: 17 Test RMSE: tensor(49.0340) Test Planets: 2
# Epoch: 18 Test RMSE: tensor(43.8386) Test Planets: 4
# Epoch: 19 Test RMSE: tensor(29.3898) Test Planets: 3
# Epoch: 20 Test RMSE: tensor(35.9455) Test Planets: 2
# Epoch: 21 Test RMSE: tensor(48.4161) Test Planets: 1
# Epoch: 22 Test RMSE: tensor(35.8109) Test Planets: 3
# Epoch: 23 Test RMSE: tensor(32.9332) Test Planets: 4
# Epoch: 24 Test RMSE: tensor(25.7867) Test Planets: 4
# Epoch: 25 Test RMSE: tensor(44.8909) Test Planets: 1
# Epoch: 26 Test RMSE: tensor(27.5324) Test Planets: 4
# Epoch: 27 Test RMSE: tensor(27.0818) Test Planets: 5
# Epoch: 28 Test RMSE: tensor(33.0317) Test Planets: 3
# Epoch: 29 Test RMSE: tensor(28.4952) Test Planets: 5
# Epoch: 30 Test RMSE: tensor(40.0078) Test Planets: 1
# Epoch: 31 Test RMSE: tensor(28.0369) Test Planets: 3
# Epoch: 32 Test RMSE: tensor(37.9208) Test Planets: 1
# Epoch: 33 Test RMSE: tensor(36.2792) Test Planets: 3
# Epoch: 34 Test RMSE: tensor(35.7653) Test Planets: 1
# Epoch: 35 Test RMSE: tensor(30.4638) Test Planets: 5
# Epoch: 36 Test RMSE: tensor(26.1088) Test Planets: 3
# Epoch: 37 Test RMSE: tensor(21.0148) Test Planets: 5
# Epoch: 38 Test RMSE: tensor(22.1682) Test Planets: 4
# Epoch: 39 Test RMSE: tensor(22.0353) Test Planets: 2
# Epoch: 40 Test RMSE: tensor(20.9826) Test Planets: 4
# Epoch: 41 Test RMSE: tensor(31.8015) Test Planets: 4
# Epoch: 42 Test RMSE: tensor(16.8953) Test Planets: 3
# Epoch: 43 Test RMSE: tensor(23.7640) Test Planets: 2
# Epoch: 44 Test RMSE: tensor(23.5212) Test Planets: 2
# Epoch: 45 Test RMSE: tensor(19.7015) Test Planets: 5
# Epoch: 46 Test RMSE: tensor(20.5856) Test Planets: 5
# Epoch: 47 Test RMSE: tensor(23.2306) Test Planets: 4
# Epoch: 48 Test RMSE: tensor(26.5194) Test Planets: 5
# Epoch: 49 Test RMSE: tensor(18.6276) Test Planets: 3
# Epoch: 50 Test RMSE: tensor(29.2645) Test Planets: 3
# Epoch: 51 Test RMSE: tensor(27.8425) Test Planets: 3
# Epoch: 52 Test RMSE: tensor(37.6906) Test Planets: 2
# Epoch: 53 Test RMSE: tensor(18.2271) Test Planets: 3
# Epoch: 54 Test RMSE: tensor(15.9682) Test Planets: 4
# Epoch: 55 Test RMSE: tensor(14.4226) Test Planets: 4
# Epoch: 56 Test RMSE: tensor(10.1300) Test Planets: 1
# Epoch: 57 Test RMSE: tensor(10.3349) Test Planets: 2
# Epoch: 58 Test RMSE: tensor(22.9951) Test Planets: 3
# Epoch: 59 Test RMSE: tensor(27.3436) Test Planets: 2
# Epoch: 60 Test RMSE: tensor(24.6503) Test Planets: 5
# Epoch: 61 Test RMSE: tensor(21.3990) Test Planets: 4
# Epoch: 62 Test RMSE: tensor(28.0150) Test Planets: 5
# Epoch: 63 Test RMSE: tensor(8.7667) Test Planets: 3
# Epoch: 64 Test RMSE: tensor(11.8421) Test Planets: 5
# Epoch: 65 Test RMSE: tensor(14.8101) Test Planets: 3
# Epoch: 66 Test RMSE: tensor(24.9472) Test Planets: 2
# Epoch: 67 Test RMSE: tensor(19.1095) Test Planets: 3
# Epoch: 68 Test RMSE: tensor(7.8864) Test Planets: 4
# Epoch: 69 Test RMSE: tensor(21.6695) Test Planets: 4
# Epoch: 70 Test RMSE: tensor(6.7719) Test Planets: 2
# Epoch: 71 Test RMSE: tensor(1.4514) Test Planets: 1
# Epoch: 72 Test RMSE: tensor(17.7013) Test Planets: 3
# Epoch: 73 Test RMSE: tensor(18.8364) Test Planets: 5
# Epoch: 74 Test RMSE: tensor(12.5085) Test Planets: 5
# Epoch: 75 Test RMSE: tensor(12.9991) Test Planets: 2
# Epoch: 76 Test RMSE: tensor(20.5650) Test Planets: 5
# Epoch: 77 Test RMSE: tensor(2.8614) Test Planets: 1
# Epoch: 78 Test RMSE: tensor(2.9818) Test Planets: 1
# Epoch: 79 Test RMSE: tensor(3.0815) Test Planets: 1
# Epoch: 80 Test RMSE: tensor(23.1443) Test Planets: 5
# Epoch: 81 Test RMSE: tensor(9.7573) Test Planets: 5
# Epoch: 82 Test RMSE: tensor(16.6229) Test Planets: 5
# Epoch: 83 Test RMSE: tensor(28.8348) Test Planets: 4
# Epoch: 84 Test RMSE: tensor(13.7399) Test Planets: 5
# Epoch: 85 Test RMSE: tensor(2.9952) Test Planets: 1
# Epoch: 86 Test RMSE: tensor(13.8331) Test Planets: 5
# Epoch: 87 Test RMSE: tensor(11.5158) Test Planets: 3
# Epoch: 88 Test RMSE: tensor(8.6026) Test Planets: 3
# Epoch: 89 Test RMSE: tensor(7.2335) Test Planets: 3
# Epoch: 90 Test RMSE: tensor(8.7396) Test Planets: 3
# Epoch: 91 Test RMSE: tensor(16.0666) Test Planets: 4
# Epoch: 92 Test RMSE: tensor(2.2766) Test Planets: 1
# Epoch: 93 Test RMSE: tensor(15.8951) Test Planets: 3
# Epoch: 94 Test RMSE: tensor(24.5418) Test Planets: 5
# Epoch: 95 Test RMSE: tensor(19.6978) Test Planets: 4
# Epoch: 96 Test RMSE: tensor(1.6684) Test Planets: 1
# Epoch: 97 Test RMSE: tensor(6.8931) Test Planets: 4
# Epoch: 98 Test RMSE: tensor(13.2352) Test Planets: 5
# Epoch: 99 Test RMSE: tensor(16.6039) Test Planets: 5
# Epoch: 100 Test RMSE: tensor(22.1085) Test Planets: 5
# Epoch: 101 Test RMSE: tensor(8.3099) Test Planets: 3
# Epoch: 102 Test RMSE: tensor(0.8389) Test Planets: 1
# Epoch: 103 Test RMSE: tensor(6.6767) Test Planets: 2
# Epoch: 104 Test RMSE: tensor(3.6206) Test Planets: 2
# Epoch: 105 Test RMSE: tensor(0.3197) Test Planets: 1
# Epoch: 106 Test RMSE: tensor(6.0392) Test Planets: 2
# Epoch: 107 Test RMSE: tensor(7.6142) Test Planets: 2
# Epoch: 108 Test RMSE: tensor(14.8648) Test Planets: 4
# Epoch: 109 Test RMSE: tensor(8.3348) Test Planets: 2
# Epoch: 110 Test RMSE: tensor(15.0256) Test Planets: 3
# Epoch: 111 Test RMSE: tensor(0.0401) Test Planets: 1
# Epoch: 112 Test RMSE: tensor(0.0156) Test Planets: 1
# Epoch: 113 Test RMSE: tensor(9.2529) Test Planets: 4
# Epoch: 114 Test RMSE: tensor(10.0753) Test Planets: 3
# Epoch: 115 Test RMSE: tensor(12.6469) Test Planets: 5
# Epoch: 116 Test RMSE: tensor(20.2375) Test Planets: 2
# Epoch: 117 Test RMSE: tensor(10.2061) Test Planets: 2
# Epoch: 118 Test RMSE: tensor(9.1449) Test Planets: 2
# Epoch: 119 Test RMSE: tensor(16.7950) Test Planets: 4
# Epoch: 120 Test RMSE: tensor(0.5749) Test Planets: 1
# Epoch: 121 Test RMSE: tensor(15.9863) Test Planets: 5
# Epoch: 122 Test RMSE: tensor(13.0750) Test Planets: 4
# Epoch: 123 Test RMSE: tensor(0.3984) Test Planets: 1
# Epoch: 124 Test RMSE: tensor(0.3876) Test Planets: 1
# Epoch: 125 Test RMSE: tensor(8.0230) Test Planets: 5
# Epoch: 126 Test RMSE: tensor(0.5022) Test Planets: 1
# Epoch: 127 Test RMSE: tensor(0.5682) Test Planets: 1
# Epoch: 128 Test RMSE: tensor(13.3281) Test Planets: 5
# Epoch: 129 Test RMSE: tensor(5.9923) Test Planets: 5
# Epoch: 130 Test RMSE: tensor(0.6012) Test Planets: 1
# Epoch: 131 Test RMSE: tensor(8.6603) Test Planets: 5
# Epoch: 132 Test RMSE: tensor(8.1292) Test Planets: 5
# Epoch: 133 Test RMSE: tensor(3.6691) Test Planets: 2
# Epoch: 134 Test RMSE: tensor(7.7443) Test Planets: 4
# Epoch: 135 Test RMSE: tensor(9.0284) Test Planets: 5
# Epoch: 136 Test RMSE: tensor(11.7737) Test Planets: 4
# Epoch: 137 Test RMSE: tensor(1.8980) Test Planets: 2
# Epoch: 138 Test RMSE: tensor(0.4856) Test Planets: 1
# Epoch: 139 Test RMSE: tensor(5.0507) Test Planets: 5
# Epoch: 140 Test RMSE: tensor(0.4076) Test Planets: 1
# Epoch: 141 Test RMSE: tensor(6.0783) Test Planets: 4
# Epoch: 142 Test RMSE: tensor(6.5682) Test Planets: 5
# Epoch: 143 Test RMSE: tensor(5.3542) Test Planets: 3
# Epoch: 144 Test RMSE: tensor(13.6825) Test Planets: 3
# Epoch: 145 Test RMSE: tensor(0.3270) Test Planets: 1
# Epoch: 146 Test RMSE: tensor(8.0794) Test Planets: 2
# Epoch: 147 Test RMSE: tensor(8.5088) Test Planets: 4
# Epoch: 148 Test RMSE: tensor(5.4271) Test Planets: 5
# Epoch: 149 Test RMSE: tensor(0.6310) Test Planets: 1
# Epoch: 150 Test RMSE: tensor(5.0311) Test Planets: 4
# Epoch: 151 Test RMSE: tensor(1.5216) Test Planets: 2
# Epoch: 152 Test RMSE: tensor(3.7739) Test Planets: 2
# Epoch: 153 Test RMSE: tensor(5.9397) Test Planets: 2
# Epoch: 154 Test RMSE: tensor(8.2425) Test Planets: 4
# Epoch: 155 Test RMSE: tensor(8.7355) Test Planets: 2
# Epoch: 156 Test RMSE: tensor(3.6404) Test Planets: 4
# Epoch: 157 Test RMSE: tensor(6.1651) Test Planets: 5
# Epoch: 158 Test RMSE: tensor(7.0295) Test Planets: 3
# Epoch: 159 Test RMSE: tensor(0.7155) Test Planets: 1
# Epoch: 160 Test RMSE: tensor(3.2399) Test Planets: 2
# Epoch: 161 Test RMSE: tensor(4.5164) Test Planets: 2
# Epoch: 162 Test RMSE: tensor(3.8415) Test Planets: 4
# Epoch: 163 Test RMSE: tensor(0.6848) Test Planets: 1
# Epoch: 164 Test RMSE: tensor(6.4087) Test Planets: 3
# Epoch: 165 Test RMSE: tensor(0.5392) Test Planets: 1
# Epoch: 166 Test RMSE: tensor(6.2216) Test Planets: 5
# Epoch: 167 Test RMSE: tensor(0.4153) Test Planets: 1
# Epoch: 168 Test RMSE: tensor(3.8263) Test Planets: 2
# Epoch: 169 Test RMSE: tensor(4.8711) Test Planets: 5
# Epoch: 170 Test RMSE: tensor(3.2244) Test Planets: 2
# Epoch: 171 Test RMSE: tensor(0.4128) Test Planets: 1
# Epoch: 172 Test RMSE: tensor(0.3916) Test Planets: 1
# Epoch: 173 Test RMSE: tensor(6.6291) Test Planets: 5
# Epoch: 174 Test RMSE: tensor(0.3575) Test Planets: 1
# Epoch: 175 Test RMSE: tensor(8.2610) Test Planets: 3
# Epoch: 176 Test RMSE: tensor(6.5836) Test Planets: 4
# Epoch: 177 Test RMSE: tensor(5.5873) Test Planets: 2
# Epoch: 178 Test RMSE: tensor(4.3039) Test Planets: 4
# Epoch: 179 Test RMSE: tensor(0.1219) Test Planets: 1
# Epoch: 180 Test RMSE: tensor(4.5016) Test Planets: 3
# Epoch: 181 Test RMSE: tensor(0.1750) Test Planets: 1
# Epoch: 182 Test RMSE: tensor(3.5820) Test Planets: 2
# Epoch: 183 Test RMSE: tensor(6.5821) Test Planets: 5
# Epoch: 184 Test RMSE: tensor(7.9403) Test Planets: 5
# Epoch: 185 Test RMSE: tensor(7.8543) Test Planets: 2
# Epoch: 186 Test RMSE: tensor(2.1882) Test Planets: 2
# Epoch: 187 Test RMSE: tensor(7.1488) Test Planets: 3
# Epoch: 188 Test RMSE: tensor(2.8801) Test Planets: 2
# Epoch: 189 Test RMSE: tensor(5.9624) Test Planets: 3
# Epoch: 190 Test RMSE: tensor(4.8477) Test Planets: 4
# Epoch: 191 Test RMSE: tensor(4.2398) Test Planets: 4
# Epoch: 192 Test RMSE: tensor(0.3489) Test Planets: 1
# Epoch: 193 Test RMSE: tensor(4.0906) Test Planets: 2
# Epoch: 194 Test RMSE: tensor(0.1313) Test Planets: 1
# Epoch: 195 Test RMSE: tensor(4.4572) Test Planets: 5
# Epoch: 196 Test RMSE: tensor(3.8897) Test Planets: 4
# Epoch: 197 Test RMSE: tensor(3.0725) Test Planets: 2
# Epoch: 198 Test RMSE: tensor(5.2922) Test Planets: 5
# Epoch: 199 Test RMSE: tensor(4.6323) Test Planets: 2
# Epoch: 200 Test RMSE: tensor(7.0691) Test Planets: 3
# Epoch: 201 Test RMSE: tensor(5.2836) Test Planets: 5
# Epoch: 202 Test RMSE: tensor(2.9105) Test Planets: 3
# Epoch: 203 Test RMSE: tensor(3.3169) Test Planets: 2
# Epoch: 204 Test RMSE: tensor(4.7454) Test Planets: 5
# Epoch: 205 Test RMSE: tensor(3.7439) Test Planets: 4
# Epoch: 206 Test RMSE: tensor(3.9736) Test Planets: 2
# Epoch: 207 Test RMSE: tensor(4.8681) Test Planets: 3
# Epoch: 208 Test RMSE: tensor(3.8775) Test Planets: 5
# Epoch: 209 Test RMSE: tensor(3.1717) Test Planets: 2
# Epoch: 210 Test RMSE: tensor(2.1657) Test Planets: 2
# Epoch: 211 Test RMSE: tensor(5.0140) Test Planets: 4
# Epoch: 212 Test RMSE: tensor(2.1577) Test Planets: 3
# Epoch: 213 Test RMSE: tensor(0.3421) Test Planets: 1
# Epoch: 214 Test RMSE: tensor(2.7073) Test Planets: 3
# Epoch: 215 Test RMSE: tensor(4.2730) Test Planets: 3
# Epoch: 216 Test RMSE: tensor(5.8181) Test Planets: 5
# Epoch: 217 Test RMSE: tensor(7.0668) Test Planets: 3
# Epoch: 218 Test RMSE: tensor(3.7850) Test Planets: 4
# Epoch: 219 Test RMSE: tensor(0.0885) Test Planets: 1
# Epoch: 220 Test RMSE: tensor(4.6678) Test Planets: 4
# Epoch: 221 Test RMSE: tensor(0.1206) Test Planets: 1
# Epoch: 222 Test RMSE: tensor(5.7054) Test Planets: 3
# Epoch: 223 Test RMSE: tensor(6.5568) Test Planets: 5
# Epoch: 224 Test RMSE: tensor(3.5050) Test Planets: 2
# Epoch: 225 Test RMSE: tensor(5.6280) Test Planets: 4
# Epoch: 226 Test RMSE: tensor(4.8828) Test Planets: 5
# Epoch: 227 Test RMSE: tensor(0.5479) Test Planets: 1
# Epoch: 228 Test RMSE: tensor(2.5576) Test Planets: 4
# Epoch: 229 Test RMSE: tensor(4.1992) Test Planets: 3
# Epoch: 230 Test RMSE: tensor(0.4518) Test Planets: 1
# Epoch: 231 Test RMSE: tensor(2.7198) Test Planets: 2
# Epoch: 232 Test RMSE: tensor(2.5315) Test Planets: 2
# Epoch: 233 Test RMSE: tensor(2.6428) Test Planets: 2
# Epoch: 234 Test RMSE: tensor(6.2681) Test Planets: 3
# Epoch: 235 Test RMSE: tensor(0.5523) Test Planets: 1
# Epoch: 236 Test RMSE: tensor(2.4932) Test Planets: 3
# Epoch: 237 Test RMSE: tensor(0.7029) Test Planets: 1
# Epoch: 238 Test RMSE: tensor(2.9829) Test Planets: 5
# Epoch: 239 Test RMSE: tensor(6.1220) Test Planets: 5
# Epoch: 240 Test RMSE: tensor(4.4832) Test Planets: 5
# Epoch: 241 Test RMSE: tensor(0.8330) Test Planets: 1
# Epoch: 242 Test RMSE: tensor(2.0010) Test Planets: 2
# Epoch: 243 Test RMSE: tensor(3.0507) Test Planets: 3
# Epoch: 244 Test RMSE: tensor(3.1017) Test Planets: 2
# Epoch: 245 Test RMSE: tensor(1.6611) Test Planets: 2
# Epoch: 246 Test RMSE: tensor(2.8488) Test Planets: 4
# Epoch: 247 Test RMSE: tensor(3.3894) Test Planets: 2
# Epoch: 248 Test RMSE: tensor(4.4494) Test Planets: 5
# Epoch: 249 Test RMSE: tensor(4.0216) Test Planets: 4
# Epoch: 250 Test RMSE: tensor(2.2666) Test Planets: 2
# Epoch: 251 Test RMSE: tensor(5.7215) Test Planets: 4
# Epoch: 252 Test RMSE: tensor(0.7616) Test Planets: 1
# Epoch: 253 Test RMSE: tensor(3.2102) Test Planets: 4
# Epoch: 254 Test RMSE: tensor(3.1769) Test Planets: 5
# Epoch: 255 Test RMSE: tensor(4.1755) Test Planets: 5
# Epoch: 256 Test RMSE: tensor(0.7211) Test Planets: 1
# Epoch: 257 Test RMSE: tensor(3.2965) Test Planets: 4
# Epoch: 258 Test RMSE: tensor(3.9697) Test Planets: 4
# Epoch: 259 Test RMSE: tensor(4.6791) Test Planets: 2
# Epoch: 260 Test RMSE: tensor(1.0701) Test Planets: 2
# Epoch: 261 Test RMSE: tensor(1.9513) Test Planets: 3
# Epoch: 262 Test RMSE: tensor(3.9656) Test Planets: 4
# Epoch: 263 Test RMSE: tensor(5.2113) Test Planets: 5
# Epoch: 264 Test RMSE: tensor(0.2279) Test Planets: 1
# Epoch: 265 Test RMSE: tensor(0.2956) Test Planets: 1
# Epoch: 266 Test RMSE: tensor(7.1900) Test Planets: 5
# Epoch: 267 Test RMSE: tensor(8.8121) Test Planets: 5
# Epoch: 268 Test RMSE: tensor(2.5146) Test Planets: 3
# Epoch: 269 Test RMSE: tensor(7.3729) Test Planets: 5
# Epoch: 270 Test RMSE: tensor(6.4645) Test Planets: 5
# Epoch: 271 Test RMSE: tensor(0.6598) Test Planets: 1
# Epoch: 272 Test RMSE: tensor(3.5834) Test Planets: 4
# Epoch: 273 Test RMSE: tensor(3.7567) Test Planets: 4
# Epoch: 274 Test RMSE: tensor(3.8126) Test Planets: 3
# Epoch: 275 Test RMSE: tensor(0.6139) Test Planets: 1
# Epoch: 276 Test RMSE: tensor(0.5868) Test Planets: 1
# Epoch: 277 Test RMSE: tensor(0.5097) Test Planets: 1
# Epoch: 278 Test RMSE: tensor(0.4371) Test Planets: 1
# Epoch: 279 Test RMSE: tensor(4.7133) Test Planets: 5
# Epoch: 280 Test RMSE: tensor(5.1079) Test Planets: 4
# Epoch: 281 Test RMSE: tensor(3.7872) Test Planets: 4
# Epoch: 282 Test RMSE: tensor(3.3132) Test Planets: 4
# Epoch: 283 Test RMSE: tensor(0.1087) Test Planets: 1
# Epoch: 284 Test RMSE: tensor(2.1955) Test Planets: 2
# Epoch: 285 Test RMSE: tensor(1.4588) Test Planets: 3
# Epoch: 286 Test RMSE: tensor(2.6320) Test Planets: 5
# Epoch: 287 Test RMSE: tensor(3.5407) Test Planets: 5
# Epoch: 288 Test RMSE: tensor(4.9798) Test Planets: 5
# Epoch: 289 Test RMSE: tensor(3.8916) Test Planets: 4
# Epoch: 290 Test RMSE: tensor(3.0140) Test Planets: 3
# Epoch: 291 Test RMSE: tensor(2.8947) Test Planets: 5
# Epoch: 292 Test RMSE: tensor(3.0446) Test Planets: 4
# Epoch: 293 Test RMSE: tensor(4.6327) Test Planets: 2
# Epoch: 294 Test RMSE: tensor(2.8906) Test Planets: 4
# Epoch: 295 Test RMSE: tensor(1.3347) Test Planets: 1
# Epoch: 296 Test RMSE: tensor(1.3740) Test Planets: 1
# Epoch: 297 Test RMSE: tensor(3.7440) Test Planets: 3
# Epoch: 298 Test RMSE: tensor(1.9032) Test Planets: 2
# Epoch: 299 Test RMSE: tensor(3.6784) Test Planets: 3
# Epoch: 300 Test RMSE: tensor(1.5188) Test Planets: 1
# Epoch: 301 Test RMSE: tensor(3.4519) Test Planets: 5
# Epoch: 302 Test RMSE: tensor(2.9694) Test Planets: 5
# Epoch: 303 Test RMSE: tensor(1.5053) Test Planets: 1
# Epoch: 304 Test RMSE: tensor(1.5220) Test Planets: 1
# Epoch: 305 Test RMSE: tensor(2.3278) Test Planets: 3
# Epoch: 306 Test RMSE: tensor(2.3243) Test Planets: 5
# Epoch: 307 Test RMSE: tensor(2.0878) Test Planets: 2
# Epoch: 308 Test RMSE: tensor(4.9413) Test Planets: 4
# Epoch: 309 Test RMSE: tensor(3.4828) Test Planets: 4
# Epoch: 310 Test RMSE: tensor(5.7830) Test Planets: 4
# Epoch: 311 Test RMSE: tensor(0.4860) Test Planets: 1
# Epoch: 312 Test RMSE: tensor(0.5140) Test Planets: 1
# Epoch: 313 Test RMSE: tensor(3.7829) Test Planets: 5
# Epoch: 314 Test RMSE: tensor(2.2471) Test Planets: 2
# Epoch: 315 Test RMSE: tensor(0.6846) Test Planets: 1
# Epoch: 316 Test RMSE: tensor(4.1769) Test Planets: 5
# Epoch: 317 Test RMSE: tensor(5.6062) Test Planets: 2
# Epoch: 318 Test RMSE: tensor(3.0777) Test Planets: 3
# Epoch: 319 Test RMSE: tensor(0.7626) Test Planets: 1
# Epoch: 320 Test RMSE: tensor(2.0893) Test Planets: 2
# Epoch: 321 Test RMSE: tensor(8.9126) Test Planets: 5
# Epoch: 322 Test RMSE: tensor(3.6052) Test Planets: 4
# Epoch: 323 Test RMSE: tensor(0.3247) Test Planets: 1
# Epoch: 324 Test RMSE: tensor(3.5378) Test Planets: 3
# Epoch: 325 Test RMSE: tensor(4.2745) Test Planets: 4
# Epoch: 326 Test RMSE: tensor(2.6213) Test Planets: 2
# Epoch: 327 Test RMSE: tensor(0.9826) Test Planets: 2
# Epoch: 328 Test RMSE: tensor(3.0766) Test Planets: 5
# Epoch: 329 Test RMSE: tensor(0.7883) Test Planets: 1
# Epoch: 330 Test RMSE: tensor(0.6965) Test Planets: 1
# Epoch: 331 Test RMSE: tensor(4.8151) Test Planets: 5
# Epoch: 332 Test RMSE: tensor(4.9846) Test Planets: 2
# Epoch: 333 Test RMSE: tensor(2.6473) Test Planets: 4
# Epoch: 334 Test RMSE: tensor(2.4885) Test Planets: 4
# Epoch: 335 Test RMSE: tensor(1.5499) Test Planets: 2
# Epoch: 336 Test RMSE: tensor(4.6716) Test Planets: 2
# Epoch: 337 Test RMSE: tensor(1.2026) Test Planets: 2
# Epoch: 338 Test RMSE: tensor(1.4240) Test Planets: 2
# Epoch: 339 Test RMSE: tensor(0.6954) Test Planets: 1
# Epoch: 340 Test RMSE: tensor(1.6469) Test Planets: 4
# Epoch: 341 Test RMSE: tensor(2.5043) Test Planets: 2
# Epoch: 342 Test RMSE: tensor(1.9668) Test Planets: 2
# Epoch: 343 Test RMSE: tensor(1.0236) Test Planets: 1
# Epoch: 344 Test RMSE: tensor(5.8206) Test Planets: 4
# Epoch: 345 Test RMSE: tensor(2.2970) Test Planets: 4
# Epoch: 346 Test RMSE: tensor(2.8943) Test Planets: 3
# Epoch: 347 Test RMSE: tensor(3.8439) Test Planets: 5
# Epoch: 348 Test RMSE: tensor(1.8205) Test Planets: 2
# Epoch: 349 Test RMSE: tensor(3.5197) Test Planets: 2
# Epoch: 350 Test RMSE: tensor(3.0714) Test Planets: 4
# Epoch: 351 Test RMSE: tensor(3.9866) Test Planets: 4
# Epoch: 352 Test RMSE: tensor(5.0074) Test Planets: 4
# Epoch: 353 Test RMSE: tensor(3.9794) Test Planets: 2
# Epoch: 354 Test RMSE: tensor(2.4320) Test Planets: 3
# Epoch: 355 Test RMSE: tensor(0.9842) Test Planets: 1
# Epoch: 356 Test RMSE: tensor(0.7912) Test Planets: 1
# Epoch: 357 Test RMSE: tensor(0.6343) Test Planets: 1
# Epoch: 358 Test RMSE: tensor(3.0395) Test Planets: 4
# Epoch: 359 Test RMSE: tensor(2.2966) Test Planets: 3
# Epoch: 360 Test RMSE: tensor(0.3957) Test Planets: 1
# Epoch: 361 Test RMSE: tensor(0.3863) Test Planets: 1
# Epoch: 362 Test RMSE: tensor(1.8540) Test Planets: 3
# Epoch: 363 Test RMSE: tensor(3.0909) Test Planets: 5
# Epoch: 364 Test RMSE: tensor(1.8969) Test Planets: 3
# Epoch: 365 Test RMSE: tensor(2.4371) Test Planets: 4
# Epoch: 366 Test RMSE: tensor(1.7479) Test Planets: 3
# Epoch: 367 Test RMSE: tensor(2.7734) Test Planets: 3
# Epoch: 368 Test RMSE: tensor(3.0407) Test Planets: 5
# Epoch: 369 Test RMSE: tensor(0.6186) Test Planets: 1
# Epoch: 370 Test RMSE: tensor(1.8644) Test Planets: 4
# Epoch: 371 Test RMSE: tensor(2.6109) Test Planets: 3
# Epoch: 372 Test RMSE: tensor(1.4747) Test Planets: 2
# Epoch: 373 Test RMSE: tensor(0.5575) Test Planets: 1
# Epoch: 374 Test RMSE: tensor(2.3184) Test Planets: 4
# Epoch: 375 Test RMSE: tensor(2.4079) Test Planets: 4
# Epoch: 376 Test RMSE: tensor(1.9324) Test Planets: 4
# Epoch: 377 Test RMSE: tensor(1.3341) Test Planets: 2
# Epoch: 378 Test RMSE: tensor(1.7558) Test Planets: 4
# Epoch: 379 Test RMSE: tensor(2.6926) Test Planets: 4
# Epoch: 380 Test RMSE: tensor(2.7946) Test Planets: 2
# Epoch: 381 Test RMSE: tensor(0.1604) Test Planets: 1
# Epoch: 382 Test RMSE: tensor(2.1046) Test Planets: 3
# Epoch: 383 Test RMSE: tensor(2.1135) Test Planets: 3
# Epoch: 384 Test RMSE: tensor(3.3374) Test Planets: 3
# Epoch: 385 Test RMSE: tensor(2.2135) Test Planets: 5
# Epoch: 386 Test RMSE: tensor(1.9238) Test Planets: 5
# Epoch: 387 Test RMSE: tensor(2.1120) Test Planets: 4
# Epoch: 388 Test RMSE: tensor(1.6746) Test Planets: 4
# Epoch: 389 Test RMSE: tensor(2.0281) Test Planets: 2
# Epoch: 390 Test RMSE: tensor(2.8075) Test Planets: 4
# Epoch: 391 Test RMSE: tensor(3.3652) Test Planets: 3
# Epoch: 392 Test RMSE: tensor(0.6332) Test Planets: 1
# Epoch: 393 Test RMSE: tensor(2.4126) Test Planets: 2
# Epoch: 394 Test RMSE: tensor(2.3304) Test Planets: 3
# Epoch: 395 Test RMSE: tensor(0.3715) Test Planets: 1
# Epoch: 396 Test RMSE: tensor(1.6572) Test Planets: 3
# Epoch: 397 Test RMSE: tensor(1.3758) Test Planets: 3
# Epoch: 398 Test RMSE: tensor(2.4120) Test Planets: 2
# Epoch: 399 Test RMSE: tensor(2.1875) Test Planets: 5
# Epoch: 400 Test RMSE: tensor(0.3158) Test Planets: 1
# Epoch: 401 Test RMSE: tensor(0.3572) Test Planets: 1
# Epoch: 402 Test RMSE: tensor(3.3344) Test Planets: 5
# Epoch: 403 Test RMSE: tensor(2.2673) Test Planets: 5
# Epoch: 404 Test RMSE: tensor(2.4325) Test Planets: 5
# Epoch: 405 Test RMSE: tensor(3.2226) Test Planets: 5
# Epoch: 406 Test RMSE: tensor(1.8588) Test Planets: 4
# Epoch: 407 Test RMSE: tensor(1.1032) Test Planets: 2
# Epoch: 408 Test RMSE: tensor(1.5359) Test Planets: 4
# Epoch: 409 Test RMSE: tensor(0.2729) Test Planets: 1
# Epoch: 410 Test RMSE: tensor(2.4190) Test Planets: 4
# Epoch: 411 Test RMSE: tensor(1.6354) Test Planets: 4
# Epoch: 412 Test RMSE: tensor(0.1433) Test Planets: 1
# Epoch: 413 Test RMSE: tensor(0.1066) Test Planets: 1
# Epoch: 414 Test RMSE: tensor(2.3661) Test Planets: 4
# Epoch: 415 Test RMSE: tensor(1.3920) Test Planets: 3
# Epoch: 416 Test RMSE: tensor(3.7257) Test Planets: 2
# Epoch: 417 Test RMSE: tensor(1.8410) Test Planets: 3
# Epoch: 418 Test RMSE: tensor(0.5381) Test Planets: 1
# Epoch: 419 Test RMSE: tensor(0.9768) Test Planets: 2
# Epoch: 420 Test RMSE: tensor(2.1708) Test Planets: 4
# Epoch: 421 Test RMSE: tensor(0.9702) Test Planets: 1
# Epoch: 422 Test RMSE: tensor(1.3732) Test Planets: 2
# Epoch: 423 Test RMSE: tensor(1.1824) Test Planets: 1
# Epoch: 424 Test RMSE: tensor(1.8936) Test Planets: 2
# Epoch: 425 Test RMSE: tensor(1.8851) Test Planets: 5
# Epoch: 426 Test RMSE: tensor(1.8814) Test Planets: 5
# Epoch: 427 Test RMSE: tensor(1.8596) Test Planets: 4
# Epoch: 428 Test RMSE: tensor(2.7606) Test Planets: 5
# Epoch: 429 Test RMSE: tensor(1.7718) Test Planets: 4
# Epoch: 430 Test RMSE: tensor(2.2481) Test Planets: 4
# Epoch: 431 Test RMSE: tensor(2.8828) Test Planets: 5
# Epoch: 432 Test RMSE: tensor(1.0748) Test Planets: 1
# Epoch: 433 Test RMSE: tensor(2.2583) Test Planets: 2
# Epoch: 434 Test RMSE: tensor(1.0151) Test Planets: 1
# Epoch: 435 Test RMSE: tensor(1.9172) Test Planets: 2
# Epoch: 436 Test RMSE: tensor(0.9066) Test Planets: 1
# Epoch: 437 Test RMSE: tensor(1.4752) Test Planets: 4
# Epoch: 438 Test RMSE: tensor(1.7842) Test Planets: 2
# Epoch: 439 Test RMSE: tensor(2.6604) Test Planets: 3
# Epoch: 440 Test RMSE: tensor(2.1752) Test Planets: 4
# Epoch: 441 Test RMSE: tensor(2.3416) Test Planets: 5
# Epoch: 442 Test RMSE: tensor(1.5865) Test Planets: 2
# Epoch: 443 Test RMSE: tensor(2.3103) Test Planets: 5
# Epoch: 444 Test RMSE: tensor(1.6529) Test Planets: 5
# Epoch: 445 Test RMSE: tensor(1.7611) Test Planets: 5
# Epoch: 446 Test RMSE: tensor(3.7471) Test Planets: 5
# Epoch: 447 Test RMSE: tensor(5.0615) Test Planets: 5
# Epoch: 448 Test RMSE: tensor(0.0970) Test Planets: 1
# Epoch: 449 Test RMSE: tensor(1.9201) Test Planets: 3
# Epoch: 450 Test RMSE: tensor(1.4191) Test Planets: 2
# Epoch: 451 Test RMSE: tensor(2.8509) Test Planets: 4
# Epoch: 452 Test RMSE: tensor(1.6475) Test Planets: 4
# Epoch: 453 Test RMSE: tensor(1.8884) Test Planets: 2
# Epoch: 454 Test RMSE: tensor(1.2183) Test Planets: 3
# Epoch: 455 Test RMSE: tensor(1.2899) Test Planets: 4
# Epoch: 456 Test RMSE: tensor(0.2947) Test Planets: 1
# Epoch: 457 Test RMSE: tensor(1.9194) Test Planets: 5
# Epoch: 458 Test RMSE: tensor(3.0699) Test Planets: 4
# Epoch: 459 Test RMSE: tensor(2.0820) Test Planets: 3
# Epoch: 460 Test RMSE: tensor(2.6041) Test Planets: 5
# Epoch: 461 Test RMSE: tensor(0.9464) Test Planets: 2
# Epoch: 462 Test RMSE: tensor(1.5518) Test Planets: 3
# Epoch: 463 Test RMSE: tensor(1.6602) Test Planets: 4
# Epoch: 464 Test RMSE: tensor(0.2771) Test Planets: 1
# Epoch: 465 Test RMSE: tensor(1.7190) Test Planets: 3
# Epoch: 466 Test RMSE: tensor(1.5460) Test Planets: 4
# Epoch: 467 Test RMSE: tensor(2.2759) Test Planets: 5
# Epoch: 468 Test RMSE: tensor(1.6667) Test Planets: 2
# Epoch: 469 Test RMSE: tensor(2.1636) Test Planets: 4
# Epoch: 470 Test RMSE: tensor(2.4682) Test Planets: 5
# Epoch: 471 Test RMSE: tensor(1.8078) Test Planets: 5
# Epoch: 472 Test RMSE: tensor(0.8995) Test Planets: 1
# Epoch: 473 Test RMSE: tensor(1.3203) Test Planets: 2
# Epoch: 474 Test RMSE: tensor(1.8753) Test Planets: 3
# Epoch: 475 Test RMSE: tensor(2.3829) Test Planets: 5
# Epoch: 476 Test RMSE: tensor(1.6432) Test Planets: 5
# Epoch: 477 Test RMSE: tensor(1.2086) Test Planets: 2
# Epoch: 478 Test RMSE: tensor(0.6233) Test Planets: 1
# Epoch: 479 Test RMSE: tensor(1.7268) Test Planets: 4
# Epoch: 480 Test RMSE: tensor(0.4015) Test Planets: 1
# Epoch: 481 Test RMSE: tensor(2.2248) Test Planets: 5
# Epoch: 482 Test RMSE: tensor(0.2132) Test Planets: 1
# Epoch: 483 Test RMSE: tensor(1.8939) Test Planets: 4
# Epoch: 484 Test RMSE: tensor(2.6559) Test Planets: 5
# Epoch: 485 Test RMSE: tensor(2.3243) Test Planets: 4
# Epoch: 486 Test RMSE: tensor(3.1959) Test Planets: 3
# Epoch: 487 Test RMSE: tensor(1.6991) Test Planets: 2
# Epoch: 488 Test RMSE: tensor(1.4335) Test Planets: 4
# Epoch: 489 Test RMSE: tensor(2.1055) Test Planets: 5
# Epoch: 490 Test RMSE: tensor(1.7241) Test Planets: 3
# Epoch: 491 Test RMSE: tensor(1.9203) Test Planets: 5
# Epoch: 492 Test RMSE: tensor(1.9350) Test Planets: 2
# Epoch: 493 Test RMSE: tensor(2.8980) Test Planets: 5
# Epoch: 494 Test RMSE: tensor(1.7678) Test Planets: 5
# Epoch: 495 Test RMSE: tensor(0.8443) Test Planets: 2
# Epoch: 496 Test RMSE: tensor(1.6925) Test Planets: 4
# Epoch: 497 Test RMSE: tensor(1.6662) Test Planets: 2
# Epoch: 498 Test RMSE: tensor(2.8266) Test Planets: 3
# Epoch: 499 Test RMSE: tensor(0.4687) Test Planets: 1
# Epoch: 500 Test RMSE: tensor(1.9554) Test Planets: 3
# Epoch: 501 Test RMSE: tensor(0.2659) Test Planets: 1
# Epoch: 502 Test RMSE: tensor(2.6135) Test Planets: 5
# Epoch: 503 Test RMSE: tensor(2.0542) Test Planets: 5
# Epoch: 504 Test RMSE: tensor(1.3579) Test Planets: 3
# Epoch: 505 Test RMSE: tensor(0.3627) Test Planets: 1
# Epoch: 506 Test RMSE: tensor(2.1234) Test Planets: 2
# Epoch: 507 Test RMSE: tensor(2.0454) Test Planets: 3
# Epoch: 508 Test RMSE: tensor(1.8389) Test Planets: 3
# Epoch: 509 Test RMSE: tensor(2.0173) Test Planets: 2
# Epoch: 510 Test RMSE: tensor(1.3834) Test Planets: 2
# Epoch: 511 Test RMSE: tensor(0.4643) Test Planets: 1
# Epoch: 512 Test RMSE: tensor(2.1392) Test Planets: 4
# Epoch: 513 Test RMSE: tensor(1.7944) Test Planets: 2
# Epoch: 514 Test RMSE: tensor(2.6050) Test Planets: 5
# Epoch: 515 Test RMSE: tensor(2.4005) Test Planets: 5
# Epoch: 516 Test RMSE: tensor(1.6409) Test Planets: 2
# Epoch: 517 Test RMSE: tensor(1.8505) Test Planets: 2
# Epoch: 518 Test RMSE: tensor(1.9403) Test Planets: 5
# Epoch: 519 Test RMSE: tensor(0.4446) Test Planets: 1
# Epoch: 520 Test RMSE: tensor(0.8207) Test Planets: 3
# Epoch: 521 Test RMSE: tensor(1.7391) Test Planets: 2
# Epoch: 522 Test RMSE: tensor(3.6273) Test Planets: 3
# Epoch: 523 Test RMSE: tensor(1.6835) Test Planets: 5
# Epoch: 524 Test RMSE: tensor(0.1223) Test Planets: 1
# Epoch: 525 Test RMSE: tensor(1.4153) Test Planets: 2
# Epoch: 526 Test RMSE: tensor(0.9825) Test Planets: 2
# Epoch: 527 Test RMSE: tensor(1.6442) Test Planets: 3
# Epoch: 528 Test RMSE: tensor(3.0994) Test Planets: 5
# Epoch: 529 Test RMSE: tensor(1.5677) Test Planets: 3
# Epoch: 530 Test RMSE: tensor(3.6842) Test Planets: 2
# Epoch: 531 Test RMSE: tensor(2.2155) Test Planets: 3
# Epoch: 532 Test RMSE: tensor(2.4505) Test Planets: 2
# Epoch: 533 Test RMSE: tensor(1.2709) Test Planets: 2
# Epoch: 534 Test RMSE: tensor(2.2625) Test Planets: 4
# Epoch: 535 Test RMSE: tensor(1.7151) Test Planets: 2
# Epoch: 536 Test RMSE: tensor(1.7291) Test Planets: 5
# Epoch: 537 Test RMSE: tensor(2.1802) Test Planets: 5
# Epoch: 538 Test RMSE: tensor(0.9986) Test Planets: 2
# Epoch: 539 Test RMSE: tensor(1.5161) Test Planets: 2
# Epoch: 540 Test RMSE: tensor(2.9724) Test Planets: 5
# Epoch: 541 Test RMSE: tensor(1.5292) Test Planets: 5
# Epoch: 542 Test RMSE: tensor(1.2750) Test Planets: 5
# Epoch: 543 Test RMSE: tensor(1.6468) Test Planets: 5
# Epoch: 544 Test RMSE: tensor(1.6634) Test Planets: 5
# Epoch: 545 Test RMSE: tensor(1.0827) Test Planets: 3
# Epoch: 546 Test RMSE: tensor(2.0161) Test Planets: 5
# Epoch: 547 Test RMSE: tensor(2.2454) Test Planets: 5
# Epoch: 548 Test RMSE: tensor(1.4785) Test Planets: 2
# Epoch: 549 Test RMSE: tensor(1.1711) Test Planets: 3
# Epoch: 550 Test RMSE: tensor(0.1380) Test Planets: 1
# Epoch: 551 Test RMSE: tensor(2.6346) Test Planets: 5
# Epoch: 552 Test RMSE: tensor(2.1489) Test Planets: 5
# Epoch: 553 Test RMSE: tensor(1.1852) Test Planets: 3
# Epoch: 554 Test RMSE: tensor(2.6557) Test Planets: 2
# Epoch: 555 Test RMSE: tensor(1.7247) Test Planets: 4
# Epoch: 556 Test RMSE: tensor(1.0806) Test Planets: 3
# Epoch: 557 Test RMSE: tensor(0.2838) Test Planets: 1
# Epoch: 558 Test RMSE: tensor(0.3286) Test Planets: 1
# Epoch: 559 Test RMSE: tensor(0.3582) Test Planets: 1
# Epoch: 560 Test RMSE: tensor(0.3488) Test Planets: 1
# Epoch: 561 Test RMSE: tensor(2.2130) Test Planets: 3
# Epoch: 562 Test RMSE: tensor(2.1396) Test Planets: 2
# Epoch: 563 Test RMSE: tensor(0.5644) Test Planets: 1
# Epoch: 564 Test RMSE: tensor(1.8543) Test Planets: 3
# Epoch: 565 Test RMSE: tensor(1.6204) Test Planets: 5
# Epoch: 566 Test RMSE: tensor(2.2055) Test Planets: 5
# Epoch: 567 Test RMSE: tensor(1.1525) Test Planets: 3
# Epoch: 568 Test RMSE: tensor(2.1003) Test Planets: 5
# Epoch: 569 Test RMSE: tensor(1.4861) Test Planets: 4
# Epoch: 570 Test RMSE: tensor(0.4200) Test Planets: 1
# Epoch: 571 Test RMSE: tensor(2.2948) Test Planets: 5
# Epoch: 572 Test RMSE: tensor(1.8029) Test Planets: 5
# Epoch: 573 Test RMSE: tensor(2.8037) Test Planets: 5
# Epoch: 574 Test RMSE: tensor(1.7395) Test Planets: 5
# Epoch: 575 Test RMSE: tensor(0.2809) Test Planets: 1
# Epoch: 576 Test RMSE: tensor(2.1084) Test Planets: 4
# Epoch: 577 Test RMSE: tensor(0.9104) Test Planets: 4
# Epoch: 578 Test RMSE: tensor(1.2864) Test Planets: 2
# Epoch: 579 Test RMSE: tensor(1.4227) Test Planets: 3
# Epoch: 580 Test RMSE: tensor(2.3585) Test Planets: 2
# Epoch: 581 Test RMSE: tensor(1.1560) Test Planets: 2
# Epoch: 582 Test RMSE: tensor(1.3660) Test Planets: 5
# Epoch: 583 Test RMSE: tensor(0.3226) Test Planets: 1
# Epoch: 584 Test RMSE: tensor(1.5885) Test Planets: 5
# Epoch: 585 Test RMSE: tensor(2.0198) Test Planets: 3
# Epoch: 586 Test RMSE: tensor(0.6843) Test Planets: 2
# Epoch: 587 Test RMSE: tensor(0.3073) Test Planets: 1
# Epoch: 588 Test RMSE: tensor(1.2330) Test Planets: 4
# Epoch: 589 Test RMSE: tensor(1.7989) Test Planets: 5
# Epoch: 590 Test RMSE: tensor(0.8564) Test Planets: 2
# Epoch: 591 Test RMSE: tensor(1.3366) Test Planets: 5
# Epoch: 592 Test RMSE: tensor(0.4007) Test Planets: 1
# Epoch: 593 Test RMSE: tensor(0.5244) Test Planets: 1
# Epoch: 594 Test RMSE: tensor(2.5025) Test Planets: 2
# Epoch: 595 Test RMSE: tensor(0.6433) Test Planets: 1
# Epoch: 596 Test RMSE: tensor(1.4435) Test Planets: 3
# Epoch: 597 Test RMSE: tensor(0.7773) Test Planets: 1
# Epoch: 598 Test RMSE: tensor(1.2222) Test Planets: 2
# Epoch: 599 Test RMSE: tensor(2.1443) Test Planets: 4
# Epoch: 600 Test RMSE: tensor(1.6567) Test Planets: 5
# Epoch: 601 Test RMSE: tensor(1.7431) Test Planets: 5
# Epoch: 602 Test RMSE: tensor(1.3661) Test Planets: 3
# Epoch: 603 Test RMSE: tensor(1.4777) Test Planets: 5
# Epoch: 604 Test RMSE: tensor(2.3921) Test Planets: 5
# Epoch: 605 Test RMSE: tensor(1.1882) Test Planets: 3
# Epoch: 606 Test RMSE: tensor(1.3507) Test Planets: 2
# Epoch: 607 Test RMSE: tensor(1.4200) Test Planets: 4
# Epoch: 608 Test RMSE: tensor(1.6128) Test Planets: 5
# Epoch: 609 Test RMSE: tensor(0.7688) Test Planets: 2
# Epoch: 610 Test RMSE: tensor(0.4578) Test Planets: 1
# Epoch: 611 Test RMSE: tensor(0.4615) Test Planets: 1
# Epoch: 612 Test RMSE: tensor(2.0941) Test Planets: 5
# Epoch: 613 Test RMSE: tensor(1.9216) Test Planets: 3
# Epoch: 614 Test RMSE: tensor(2.7035) Test Planets: 5
# Epoch: 615 Test RMSE: tensor(3.4386) Test Planets: 4
# Epoch: 616 Test RMSE: tensor(3.3826) Test Planets: 3
# Epoch: 617 Test RMSE: tensor(0.3354) Test Planets: 1
# Epoch: 618 Test RMSE: tensor(0.3749) Test Planets: 1
# Epoch: 619 Test RMSE: tensor(0.5346) Test Planets: 1
# Epoch: 620 Test RMSE: tensor(2.0302) Test Planets: 2
# Epoch: 621 Test RMSE: tensor(1.4671) Test Planets: 2
# Epoch: 622 Test RMSE: tensor(7.3465) Test Planets: 3
# Epoch: 623 Test RMSE: tensor(2.2762) Test Planets: 3
# Epoch: 624 Test RMSE: tensor(3.9643) Test Planets: 4
# Epoch: 625 Test RMSE: tensor(1.3373) Test Planets: 1
# Epoch: 626 Test RMSE: tensor(2.4412) Test Planets: 5
# Epoch: 627 Test RMSE: tensor(1.7667) Test Planets: 3
# Epoch: 628 Test RMSE: tensor(3.2696) Test Planets: 3
# Epoch: 629 Test RMSE: tensor(1.0369) Test Planets: 1
# Epoch: 630 Test RMSE: tensor(5.0009) Test Planets: 3
# Epoch: 631 Test RMSE: tensor(4.9640) Test Planets: 3
# Epoch: 632 Test RMSE: tensor(3.0092) Test Planets: 4
# Epoch: 633 Test RMSE: tensor(2.5496) Test Planets: 4
# Epoch: 634 Test RMSE: tensor(1.4481) Test Planets: 3
# Epoch: 635 Test RMSE: tensor(1.6640) Test Planets: 4
# Epoch: 636 Test RMSE: tensor(2.1124) Test Planets: 3
# Epoch: 637 Test RMSE: tensor(2.9484) Test Planets: 3
# Epoch: 638 Test RMSE: tensor(1.4942) Test Planets: 3
# Epoch: 639 Test RMSE: tensor(3.2556) Test Planets: 5
# Epoch: 640 Test RMSE: tensor(2.4713) Test Planets: 2
# Epoch: 641 Test RMSE: tensor(0.6361) Test Planets: 1
# Epoch: 642 Test RMSE: tensor(2.8458) Test Planets: 5
# Epoch: 643 Test RMSE: tensor(2.9877) Test Planets: 3
# Epoch: 644 Test RMSE: tensor(0.5175) Test Planets: 1
# Epoch: 645 Test RMSE: tensor(2.3903) Test Planets: 2
# Epoch: 646 Test RMSE: tensor(0.5773) Test Planets: 1
# Epoch: 647 Test RMSE: tensor(3.0102) Test Planets: 3
# Epoch: 648 Test RMSE: tensor(1.0804) Test Planets: 2
# Epoch: 649 Test RMSE: tensor(1.3235) Test Planets: 5
# Epoch: 650 Test RMSE: tensor(0.5895) Test Planets: 1
# Epoch: 651 Test RMSE: tensor(2.2961) Test Planets: 5
# Epoch: 652 Test RMSE: tensor(1.6788) Test Planets: 5
# Epoch: 653 Test RMSE: tensor(2.6459) Test Planets: 3
# Epoch: 654 Test RMSE: tensor(1.9673) Test Planets: 5
# Epoch: 655 Test RMSE: tensor(1.2999) Test Planets: 2
# Epoch: 656 Test RMSE: tensor(2.7704) Test Planets: 3
# Epoch: 657 Test RMSE: tensor(1.2776) Test Planets: 1
# Epoch: 658 Test RMSE: tensor(1.1190) Test Planets: 1
# Epoch: 659 Test RMSE: tensor(2.5855) Test Planets: 3
# Epoch: 660 Test RMSE: tensor(2.0241) Test Planets: 5
# Epoch: 661 Test RMSE: tensor(1.9274) Test Planets: 3
# Epoch: 662 Test RMSE: tensor(1.8526) Test Planets: 5
# Epoch: 663 Test RMSE: tensor(0.2655) Test Planets: 1
# Epoch: 664 Test RMSE: tensor(0.6147) Test Planets: 2
# Epoch: 665 Test RMSE: tensor(1.7819) Test Planets: 5
# Epoch: 666 Test RMSE: tensor(1.6005) Test Planets: 3
# Epoch: 667 Test RMSE: tensor(2.5097) Test Planets: 4
# Epoch: 668 Test RMSE: tensor(3.0569) Test Planets: 3
# Epoch: 669 Test RMSE: tensor(0.8970) Test Planets: 3
# Epoch: 670 Test RMSE: tensor(0.2726) Test Planets: 1
# Epoch: 671 Test RMSE: tensor(2.6513) Test Planets: 5
# Epoch: 672 Test RMSE: tensor(2.5772) Test Planets: 4
# Epoch: 673 Test RMSE: tensor(0.0655) Test Planets: 1
# Epoch: 674 Test RMSE: tensor(0.1891) Test Planets: 1
# Epoch: 675 Test RMSE: tensor(0.3058) Test Planets: 1
# Epoch: 676 Test RMSE: tensor(1.0161) Test Planets: 2
# Epoch: 677 Test RMSE: tensor(1.6797) Test Planets: 5
# Epoch: 678 Test RMSE: tensor(1.9642) Test Planets: 5
# Epoch: 679 Test RMSE: tensor(0.5014) Test Planets: 1
# Epoch: 680 Test RMSE: tensor(1.1576) Test Planets: 2
# Epoch: 681 Test RMSE: tensor(2.3192) Test Planets: 3
# Epoch: 682 Test RMSE: tensor(1.2655) Test Planets: 5
# Epoch: 683 Test RMSE: tensor(0.5196) Test Planets: 2
# Epoch: 684 Test RMSE: tensor(0.1617) Test Planets: 1
# Epoch: 685 Test RMSE: tensor(2.9885) Test Planets: 4
# Epoch: 686 Test RMSE: tensor(2.0012) Test Planets: 2
# Epoch: 687 Test RMSE: tensor(0.9332) Test Planets: 2
# Epoch: 688 Test RMSE: tensor(1.5875) Test Planets: 4
# Epoch: 689 Test RMSE: tensor(1.0059) Test Planets: 2
# Epoch: 690 Test RMSE: tensor(0.9821) Test Planets: 2
# Epoch: 691 Test RMSE: tensor(1.8636) Test Planets: 5
# Epoch: 692 Test RMSE: tensor(1.3071) Test Planets: 5
# Epoch: 693 Test RMSE: tensor(0.3663) Test Planets: 1
# Epoch: 694 Test RMSE: tensor(2.4808) Test Planets: 2
# Epoch: 695 Test RMSE: tensor(1.8813) Test Planets: 5
# Epoch: 696 Test RMSE: tensor(1.5215) Test Planets: 3
# Epoch: 697 Test RMSE: tensor(0.6847) Test Planets: 2
# Epoch: 698 Test RMSE: tensor(0.7931) Test Planets: 2
# Epoch: 699 Test RMSE: tensor(1.6791) Test Planets: 2
# Epoch: 700 Test RMSE: tensor(1.5129) Test Planets: 5
# Epoch: 701 Test RMSE: tensor(1.1626) Test Planets: 3
# Epoch: 702 Test RMSE: tensor(1.9440) Test Planets: 4
# Epoch: 703 Test RMSE: tensor(1.8577) Test Planets: 5
# Epoch: 704 Test RMSE: tensor(0.4002) Test Planets: 1
# Epoch: 705 Test RMSE: tensor(1.7886) Test Planets: 5
# Epoch: 706 Test RMSE: tensor(1.2236) Test Planets: 2
# Epoch: 707 Test RMSE: tensor(0.9911) Test Planets: 2
# Epoch: 708 Test RMSE: tensor(1.3997) Test Planets: 2
# Epoch: 709 Test RMSE: tensor(1.7700) Test Planets: 3
# Epoch: 710 Test RMSE: tensor(0.7315) Test Planets: 2
# Epoch: 711 Test RMSE: tensor(0.2500) Test Planets: 1
# Epoch: 712 Test RMSE: tensor(0.8559) Test Planets: 2
# Epoch: 713 Test RMSE: tensor(1.5823) Test Planets: 4
# Epoch: 714 Test RMSE: tensor(1.8337) Test Planets: 5
# Epoch: 715 Test RMSE: tensor(1.2855) Test Planets: 4
# Epoch: 716 Test RMSE: tensor(1.3248) Test Planets: 3
# Epoch: 717 Test RMSE: tensor(1.7001) Test Planets: 2
# Epoch: 718 Test RMSE: tensor(0.7815) Test Planets: 2
# Epoch: 719 Test RMSE: tensor(0.9304) Test Planets: 4
# Epoch: 720 Test RMSE: tensor(1.3205) Test Planets: 3
# Epoch: 721 Test RMSE: tensor(1.4335) Test Planets: 2
# Epoch: 722 Test RMSE: tensor(1.7700) Test Planets: 5
# Epoch: 723 Test RMSE: tensor(1.1598) Test Planets: 2
# Epoch: 724 Test RMSE: tensor(1.3410) Test Planets: 3
# Epoch: 725 Test RMSE: tensor(2.1718) Test Planets: 5
# Epoch: 726 Test RMSE: tensor(0.2554) Test Planets: 1
# Epoch: 727 Test RMSE: tensor(1.8300) Test Planets: 3
# Epoch: 728 Test RMSE: tensor(0.9685) Test Planets: 2
# Epoch: 729 Test RMSE: tensor(0.7195) Test Planets: 2
# Epoch: 730 Test RMSE: tensor(1.5098) Test Planets: 4
# Epoch: 731 Test RMSE: tensor(1.0026) Test Planets: 3
# Epoch: 732 Test RMSE: tensor(1.5855) Test Planets: 4
# Epoch: 733 Test RMSE: tensor(1.1332) Test Planets: 2
# Epoch: 734 Test RMSE: tensor(1.5704) Test Planets: 4
# Epoch: 735 Test RMSE: tensor(2.0782) Test Planets: 5
# Epoch: 736 Test RMSE: tensor(0.2646) Test Planets: 1
# Epoch: 737 Test RMSE: tensor(0.3359) Test Planets: 1
# Epoch: 738 Test RMSE: tensor(0.3809) Test Planets: 1
# Epoch: 739 Test RMSE: tensor(1.7591) Test Planets: 5
# Epoch: 740 Test RMSE: tensor(1.0202) Test Planets: 4
# Epoch: 741 Test RMSE: tensor(1.2896) Test Planets: 3
# Epoch: 742 Test RMSE: tensor(1.4792) Test Planets: 5
# Epoch: 743 Test RMSE: tensor(0.2819) Test Planets: 1
# Epoch: 744 Test RMSE: tensor(1.9289) Test Planets: 3
# Epoch: 745 Test RMSE: tensor(1.6297) Test Planets: 3
# Epoch: 746 Test RMSE: tensor(1.6400) Test Planets: 3
# Epoch: 747 Test RMSE: tensor(0.7374) Test Planets: 2
# Epoch: 748 Test RMSE: tensor(1.6655) Test Planets: 5
# Epoch: 749 Test RMSE: tensor(1.7236) Test Planets: 5
# Epoch: 750 Test RMSE: tensor(1.3536) Test Planets: 4
# Epoch: 751 Test RMSE: tensor(1.6961) Test Planets: 3
# Epoch: 752 Test RMSE: tensor(0.2674) Test Planets: 1
# Epoch: 753 Test RMSE: tensor(1.3484) Test Planets: 3
# Epoch: 754 Test RMSE: tensor(1.2918) Test Planets: 5
# Epoch: 755 Test RMSE: tensor(1.2534) Test Planets: 4
# Epoch: 756 Test RMSE: tensor(2.2833) Test Planets: 3
# Epoch: 757 Test RMSE: tensor(1.5101) Test Planets: 4
# Epoch: 758 Test RMSE: tensor(2.1380) Test Planets: 3
# Epoch: 759 Test RMSE: tensor(0.6726) Test Planets: 2
# Epoch: 760 Test RMSE: tensor(1.0604) Test Planets: 2
# Epoch: 761 Test RMSE: tensor(1.4339) Test Planets: 3
# Epoch: 762 Test RMSE: tensor(1.3122) Test Planets: 4
# Epoch: 763 Test RMSE: tensor(1.0063) Test Planets: 2
# Epoch: 764 Test RMSE: tensor(0.3294) Test Planets: 1
# Epoch: 765 Test RMSE: tensor(0.6796) Test Planets: 2
# Epoch: 766 Test RMSE: tensor(1.4140) Test Planets: 3
# Epoch: 767 Test RMSE: tensor(0.5755) Test Planets: 2
# Epoch: 768 Test RMSE: tensor(1.2664) Test Planets: 3
# Epoch: 769 Test RMSE: tensor(0.3170) Test Planets: 1
# Epoch: 770 Test RMSE: tensor(1.1997) Test Planets: 3
# Epoch: 771 Test RMSE: tensor(1.3649) Test Planets: 3
# Epoch: 772 Test RMSE: tensor(2.1329) Test Planets: 3
# Epoch: 773 Test RMSE: tensor(2.0343) Test Planets: 5
# Epoch: 774 Test RMSE: tensor(0.2709) Test Planets: 1
# Epoch: 775 Test RMSE: tensor(1.4139) Test Planets: 2
# Epoch: 776 Test RMSE: tensor(1.0304) Test Planets: 2
# Epoch: 777 Test RMSE: tensor(1.1016) Test Planets: 3
# Epoch: 778 Test RMSE: tensor(0.2566) Test Planets: 1
# Epoch: 779 Test RMSE: tensor(0.9610) Test Planets: 3
# Epoch: 780 Test RMSE: tensor(0.0948) Test Planets: 1
# Epoch: 781 Test RMSE: tensor(0.1745) Test Planets: 1
# Epoch: 782 Test RMSE: tensor(0.2803) Test Planets: 1
# Epoch: 783 Test RMSE: tensor(1.0831) Test Planets: 4
# Epoch: 784 Test RMSE: tensor(0.6216) Test Planets: 2
# Epoch: 785 Test RMSE: tensor(0.3876) Test Planets: 1
# Epoch: 786 Test RMSE: tensor(1.7247) Test Planets: 5
# Epoch: 787 Test RMSE: tensor(1.0302) Test Planets: 5
# Epoch: 788 Test RMSE: tensor(0.7417) Test Planets: 2
# Epoch: 789 Test RMSE: tensor(0.8248) Test Planets: 2
# Epoch: 790 Test RMSE: tensor(1.0564) Test Planets: 2
# Epoch: 791 Test RMSE: tensor(0.6846) Test Planets: 2
# Epoch: 792 Test RMSE: tensor(0.1992) Test Planets: 1
# Epoch: 793 Test RMSE: tensor(1.1564) Test Planets: 5
# Epoch: 794 Test RMSE: tensor(0.2006) Test Planets: 1
# Epoch: 795 Test RMSE: tensor(0.1138) Test Planets: 1
# Epoch: 796 Test RMSE: tensor(0.7661) Test Planets: 2
# Epoch: 797 Test RMSE: tensor(1.6192) Test Planets: 4
# Epoch: 798 Test RMSE: tensor(1.0876) Test Planets: 2
# Epoch: 799 Test RMSE: tensor(1.6894) Test Planets: 3
# Epoch: 800 Test RMSE: tensor(0.5129) Test Planets: 1
# Epoch: 801 Test RMSE: tensor(1.5086) Test Planets: 4
# Epoch: 802 Test RMSE: tensor(1.3234) Test Planets: 2
# Epoch: 803 Test RMSE: tensor(1.5965) Test Planets: 4
# Epoch: 804 Test RMSE: tensor(1.4756) Test Planets: 4
# Epoch: 805 Test RMSE: tensor(0.6541) Test Planets: 1
# Epoch: 806 Test RMSE: tensor(1.9798) Test Planets: 5
# Epoch: 807 Test RMSE: tensor(0.6802) Test Planets: 1
# Epoch: 808 Test RMSE: tensor(2.0587) Test Planets: 3
# Epoch: 809 Test RMSE: tensor(1.3597) Test Planets: 3
# Epoch: 810 Test RMSE: tensor(1.9144) Test Planets: 4
# Epoch: 811 Test RMSE: tensor(1.3178) Test Planets: 5
# Epoch: 812 Test RMSE: tensor(1.0884) Test Planets: 3
# Epoch: 813 Test RMSE: tensor(1.1464) Test Planets: 5
# Epoch: 814 Test RMSE: tensor(1.4654) Test Planets: 3
# Epoch: 815 Test RMSE: tensor(2.0050) Test Planets: 3
# Epoch: 816 Test RMSE: tensor(1.4200) Test Planets: 3
# Epoch: 817 Test RMSE: tensor(0.4735) Test Planets: 2
# Epoch: 818 Test RMSE: tensor(0.6767) Test Planets: 3
# Epoch: 819 Test RMSE: tensor(1.2112) Test Planets: 4
# Epoch: 820 Test RMSE: tensor(1.1006) Test Planets: 3
# Epoch: 821 Test RMSE: tensor(1.4994) Test Planets: 4
# Epoch: 822 Test RMSE: tensor(0.1533) Test Planets: 1
# Epoch: 823 Test RMSE: tensor(1.9464) Test Planets: 5
# Epoch: 824 Test RMSE: tensor(0.1250) Test Planets: 1
# Epoch: 825 Test RMSE: tensor(1.3485) Test Planets: 5
# Epoch: 826 Test RMSE: tensor(2.6348) Test Planets: 4
# Epoch: 827 Test RMSE: tensor(1.8499) Test Planets: 5
# Epoch: 828 Test RMSE: tensor(1.0397) Test Planets: 4
# Epoch: 829 Test RMSE: tensor(1.1915) Test Planets: 4
# Epoch: 830 Test RMSE: tensor(0.5969) Test Planets: 1
# Epoch: 831 Test RMSE: tensor(0.5911) Test Planets: 1
# Epoch: 832 Test RMSE: tensor(1.6112) Test Planets: 3
# Epoch: 833 Test RMSE: tensor(2.5614) Test Planets: 3
# Epoch: 834 Test RMSE: tensor(1.5867) Test Planets: 4
# Epoch: 835 Test RMSE: tensor(1.2822) Test Planets: 4
# Epoch: 836 Test RMSE: tensor(0.3031) Test Planets: 1
# Epoch: 837 Test RMSE: tensor(1.9402) Test Planets: 4
# Epoch: 838 Test RMSE: tensor(1.0442) Test Planets: 2
# Epoch: 839 Test RMSE: tensor(2.2794) Test Planets: 2
# Epoch: 840 Test RMSE: tensor(1.8802) Test Planets: 5
# Epoch: 841 Test RMSE: tensor(2.6366) Test Planets: 4
# Epoch: 842 Test RMSE: tensor(1.7801) Test Planets: 5
# Epoch: 843 Test RMSE: tensor(1.3658) Test Planets: 4
# Epoch: 844 Test RMSE: tensor(2.2987) Test Planets: 3
# Epoch: 845 Test RMSE: tensor(0.8671) Test Planets: 3
# Epoch: 846 Test RMSE: tensor(0.6649) Test Planets: 2
# Epoch: 847 Test RMSE: tensor(1.7754) Test Planets: 4
# Epoch: 848 Test RMSE: tensor(1.3808) Test Planets: 2
# Epoch: 849 Test RMSE: tensor(0.2489) Test Planets: 1
# Epoch: 850 Test RMSE: tensor(2.5926) Test Planets: 4
# Epoch: 851 Test RMSE: tensor(1.4399) Test Planets: 2
# Epoch: 852 Test RMSE: tensor(1.4141) Test Planets: 3
# Epoch: 853 Test RMSE: tensor(0.3817) Test Planets: 1
# Epoch: 854 Test RMSE: tensor(1.1503) Test Planets: 4
# Epoch: 855 Test RMSE: tensor(2.3599) Test Planets: 3
# Epoch: 856 Test RMSE: tensor(2.2209) Test Planets: 3
# Epoch: 857 Test RMSE: tensor(1.1801) Test Planets: 2
# Epoch: 858 Test RMSE: tensor(2.2749) Test Planets: 5
# Epoch: 859 Test RMSE: tensor(1.5637) Test Planets: 4
# Epoch: 860 Test RMSE: tensor(0.2903) Test Planets: 1
# Epoch: 861 Test RMSE: tensor(1.7148) Test Planets: 4
# Epoch: 862 Test RMSE: tensor(2.8818) Test Planets: 4
# Epoch: 863 Test RMSE: tensor(2.1800) Test Planets: 4
# Epoch: 864 Test RMSE: tensor(0.7856) Test Planets: 1
# Epoch: 865 Test RMSE: tensor(1.9640) Test Planets: 4
# Epoch: 866 Test RMSE: tensor(1.0575) Test Planets: 2
# Epoch: 867 Test RMSE: tensor(0.2244) Test Planets: 1
# Epoch: 868 Test RMSE: tensor(2.6430) Test Planets: 5
# Epoch: 869 Test RMSE: tensor(2.1251) Test Planets: 3
# Epoch: 870 Test RMSE: tensor(2.8630) Test Planets: 5
# Epoch: 871 Test RMSE: tensor(2.6445) Test Planets: 5
# Epoch: 872 Test RMSE: tensor(1.1918) Test Planets: 2
# Epoch: 873 Test RMSE: tensor(2.0700) Test Planets: 4
# Epoch: 874 Test RMSE: tensor(0.2178) Test Planets: 1
# Epoch: 875 Test RMSE: tensor(0.2187) Test Planets: 1
# Epoch: 876 Test RMSE: tensor(3.9045) Test Planets: 5
# Epoch: 877 Test RMSE: tensor(1.8571) Test Planets: 4
# Epoch: 878 Test RMSE: tensor(0.0398) Test Planets: 1
# Epoch: 879 Test RMSE: tensor(1.9424) Test Planets: 5
# Epoch: 880 Test RMSE: tensor(2.7463) Test Planets: 4
# Epoch: 881 Test RMSE: tensor(1.6235) Test Planets: 4
# Epoch: 882 Test RMSE: tensor(1.0841) Test Planets: 3
# Epoch: 883 Test RMSE: tensor(0.0594) Test Planets: 1
# Epoch: 884 Test RMSE: tensor(2.1346) Test Planets: 5
# Epoch: 885 Test RMSE: tensor(2.8059) Test Planets: 3
# Epoch: 886 Test RMSE: tensor(1.3287) Test Planets: 2
# Epoch: 887 Test RMSE: tensor(1.4625) Test Planets: 2
# Epoch: 888 Test RMSE: tensor(0.3836) Test Planets: 1
# Epoch: 889 Test RMSE: tensor(1.9462) Test Planets: 5
# Epoch: 890 Test RMSE: tensor(1.4493) Test Planets: 5
# Epoch: 891 Test RMSE: tensor(0.3585) Test Planets: 1
# Epoch: 892 Test RMSE: tensor(2.4269) Test Planets: 5
# Epoch: 893 Test RMSE: tensor(0.2653) Test Planets: 1
# Epoch: 894 Test RMSE: tensor(2.6232) Test Planets: 4
# Epoch: 895 Test RMSE: tensor(1.7884) Test Planets: 5
# Epoch: 896 Test RMSE: tensor(0.2264) Test Planets: 1
# Epoch: 897 Test RMSE: tensor(1.3608) Test Planets: 3
# Epoch: 898 Test RMSE: tensor(1.2640) Test Planets: 4
# Epoch: 899 Test RMSE: tensor(1.5178) Test Planets: 5
# Epoch: 900 Test RMSE: tensor(0.5450) Test Planets: 1
# Epoch: 901 Test RMSE: tensor(1.0818) Test Planets: 2
# Epoch: 902 Test RMSE: tensor(0.3810) Test Planets: 1
# Epoch: 903 Test RMSE: tensor(1.3356) Test Planets: 5
# Epoch: 904 Test RMSE: tensor(1.0010) Test Planets: 2
# Epoch: 905 Test RMSE: tensor(0.6064) Test Planets: 2
# Epoch: 906 Test RMSE: tensor(0.3253) Test Planets: 1
# Epoch: 907 Test RMSE: tensor(1.3640) Test Planets: 5
# Epoch: 908 Test RMSE: tensor(0.9333) Test Planets: 5
# Epoch: 909 Test RMSE: tensor(1.3532) Test Planets: 4
# Epoch: 910 Test RMSE: tensor(1.1012) Test Planets: 4
# Epoch: 911 Test RMSE: tensor(1.0435) Test Planets: 4
# Epoch: 912 Test RMSE: tensor(1.2929) Test Planets: 5
# Epoch: 913 Test RMSE: tensor(0.8103) Test Planets: 2
# Epoch: 914 Test RMSE: tensor(0.5725) Test Planets: 1
# Epoch: 915 Test RMSE: tensor(0.5162) Test Planets: 1
# Epoch: 916 Test RMSE: tensor(1.6244) Test Planets: 4
# Epoch: 917 Test RMSE: tensor(1.0154) Test Planets: 3
# Epoch: 918 Test RMSE: tensor(1.2374) Test Planets: 4
# Epoch: 919 Test RMSE: tensor(1.1423) Test Planets: 3
# Epoch: 920 Test RMSE: tensor(1.8415) Test Planets: 4
# Epoch: 921 Test RMSE: tensor(2.1297) Test Planets: 3
# Epoch: 922 Test RMSE: tensor(1.5772) Test Planets: 3
# Epoch: 923 Test RMSE: tensor(0.6447) Test Planets: 3
# Epoch: 924 Test RMSE: tensor(0.6303) Test Planets: 3
# Epoch: 925 Test RMSE: tensor(1.1029) Test Planets: 3
# Epoch: 926 Test RMSE: tensor(2.2307) Test Planets: 5
# Epoch: 927 Test RMSE: tensor(1.2691) Test Planets: 4
# Epoch: 928 Test RMSE: tensor(1.2117) Test Planets: 5
# Epoch: 929 Test RMSE: tensor(0.9848) Test Planets: 2
# Epoch: 930 Test RMSE: tensor(0.5871) Test Planets: 1
# Epoch: 931 Test RMSE: tensor(0.7305) Test Planets: 2
# Epoch: 932 Test RMSE: tensor(1.3732) Test Planets: 5
# Epoch: 933 Test RMSE: tensor(1.0822) Test Planets: 4
# Epoch: 934 Test RMSE: tensor(1.7563) Test Planets: 5
# Epoch: 935 Test RMSE: tensor(1.5334) Test Planets: 5
# Epoch: 936 Test RMSE: tensor(1.2399) Test Planets: 3
# Epoch: 937 Test RMSE: tensor(1.4844) Test Planets: 4
# Epoch: 938 Test RMSE: tensor(0.8578) Test Planets: 5
# Epoch: 939 Test RMSE: tensor(0.2322) Test Planets: 1
# Epoch: 940 Test RMSE: tensor(0.9557) Test Planets: 4
# Epoch: 941 Test RMSE: tensor(1.5905) Test Planets: 5
# Epoch: 942 Test RMSE: tensor(0.9775) Test Planets: 4
# Epoch: 943 Test RMSE: tensor(0.9200) Test Planets: 3
# Epoch: 944 Test RMSE: tensor(1.9119) Test Planets: 3
# Epoch: 945 Test RMSE: tensor(0.3983) Test Planets: 1
# Epoch: 946 Test RMSE: tensor(1.3788) Test Planets: 3
# Epoch: 947 Test RMSE: tensor(0.9953) Test Planets: 5
# Epoch: 948 Test RMSE: tensor(0.2958) Test Planets: 1
# Epoch: 949 Test RMSE: tensor(1.4154) Test Planets: 2
# Epoch: 950 Test RMSE: tensor(0.2999) Test Planets: 1
# Epoch: 951 Test RMSE: tensor(1.7652) Test Planets: 4
# Epoch: 952 Test RMSE: tensor(1.0936) Test Planets: 5
# Epoch: 953 Test RMSE: tensor(1.4317) Test Planets: 4
# Epoch: 954 Test RMSE: tensor(1.1169) Test Planets: 5
# Epoch: 955 Test RMSE: tensor(0.6514) Test Planets: 3
# Epoch: 956 Test RMSE: tensor(0.8801) Test Planets: 2
# Epoch: 957 Test RMSE: tensor(0.9477) Test Planets: 3
# Epoch: 958 Test RMSE: tensor(1.6310) Test Planets: 3
# Epoch: 959 Test RMSE: tensor(1.4863) Test Planets: 5
# Epoch: 960 Test RMSE: tensor(1.0053) Test Planets: 4
# Epoch: 961 Test RMSE: tensor(0.7965) Test Planets: 2
# Epoch: 962 Test RMSE: tensor(0.3531) Test Planets: 1
# Epoch: 963 Test RMSE: tensor(0.5295) Test Planets: 1
# Epoch: 964 Test RMSE: tensor(1.9587) Test Planets: 5
# Epoch: 965 Test RMSE: tensor(0.6813) Test Planets: 1
# Epoch: 966 Test RMSE: tensor(1.3418) Test Planets: 3
# Epoch: 967 Test RMSE: tensor(1.5428) Test Planets: 3
# Epoch: 968 Test RMSE: tensor(1.8098) Test Planets: 2
# Epoch: 969 Test RMSE: tensor(1.7343) Test Planets: 3
# Epoch: 970 Test RMSE: tensor(1.4832) Test Planets: 4
# Epoch: 971 Test RMSE: tensor(0.3070) Test Planets: 1
# Epoch: 972 Test RMSE: tensor(1.4216) Test Planets: 4
# Epoch: 973 Test RMSE: tensor(1.5682) Test Planets: 4
# Epoch: 974 Test RMSE: tensor(0.3428) Test Planets: 1
# Epoch: 975 Test RMSE: tensor(1.0293) Test Planets: 4
# Epoch: 976 Test RMSE: tensor(1.2203) Test Planets: 3
# Epoch: 977 Test RMSE: tensor(1.6411) Test Planets: 5
# Epoch: 978 Test RMSE: tensor(1.4835) Test Planets: 5
# Epoch: 979 Test RMSE: tensor(0.4908) Test Planets: 2
# Epoch: 980 Test RMSE: tensor(1.0108) Test Planets: 5
# Epoch: 981 Test RMSE: tensor(1.6975) Test Planets: 5
# Epoch: 982 Test RMSE: tensor(1.5374) Test Planets: 5
# Epoch: 983 Test RMSE: tensor(0.1392) Test Planets: 1
# Epoch: 984 Test RMSE: tensor(0.1848) Test Planets: 1
# Epoch: 985 Test RMSE: tensor(1.8458) Test Planets: 4
# Epoch: 986 Test RMSE: tensor(1.7493) Test Planets: 5
# Epoch: 987 Test RMSE: tensor(1.3313) Test Planets: 5
# Epoch: 988 Test RMSE: tensor(1.0030) Test Planets: 4
# Epoch: 989 Test RMSE: tensor(2.2012) Test Planets: 5
# Epoch: 990 Test RMSE: tensor(1.2071) Test Planets: 4
# Epoch: 991 Test RMSE: tensor(1.3499) Test Planets: 3
# Epoch: 992 Test RMSE: tensor(1.3658) Test Planets: 4
# Epoch: 993 Test RMSE: tensor(0.2887) Test Planets: 1
# Epoch: 994 Test RMSE: tensor(0.2574) Test Planets: 1
# Epoch: 995 Test RMSE: tensor(0.2060) Test Planets: 1
# Epoch: 996 Test RMSE: tensor(3.8710) Test Planets: 5
# Epoch: 997 Test RMSE: tensor(1.2237) Test Planets: 4
# Epoch: 998 Test RMSE: tensor(1.0060) Test Planets: 3
# Epoch: 999 Test RMSE: tensor(0.1942) Test Planets: 1
